# %%
from pdLDS import pdLDS

# %%
from generate import generateLorenz
import numpy as np
import torch
import matplotlib.pyplot as plt


# generate_ramped_lorenz
# generate lorenz data

y, (true_y, true_x, true_D) = generateLorenz(T=1000, x0=np.array([-0.9,10,10]), noise_std=8)
# y_ = (y-y.mean())/(y.std())


Y = [torch.tensor(y_).float()]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from generate import generateLorenz
#       2 import numpy as np
#       3 import torch
#
# ModuleNotFoundError: No module named 'generate'

# %%
fig, axs = plt.subplots(2,1,figsize=(10,4))
axs[0].plot(Y[0])
axs[0].set_ylabel("noisy data")
axs[1].plot(true_x)
axs[1].set_ylabel("true latent")
plt.subplots_adjust(hspace=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fig, axs = plt.subplots(2,1,figsize=(10,4))
#       2 axs[0].plot(Y[0])
#       3 axs[0].set_ylabel("noisy data")
#
# NameError: name 'plt' is not defined

# %%
emissions_dim, latent_dim, n_dynamic_operators = 10, 3, 4

pdlds = pdLDS(emissions_dim, latent_dim, n_dynamic_operators)

# %%
# S = 200 # offset window size
S = 70

pdlds.fit(Y, S, smooth_c=True, 
                  emissions_lr = 1e-2, 
                  dynamics_lr = 1e-2, 
                  train_iters=40, 
                  weight_decay=1, 
                  init_iters=10,
                  init_smoothness=5, 
                  xi=100)
# Out:
# Initializing weights with 10 iterations
# ELBO: --:   0%|          | 0/10 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/yenho/Documents/Georgia Tech/SIP lab/dLDS/pdLDS-export/cDynamics.py:372: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mu = np.ascontiguousarray(1/l_i * (Sigma @ Phi.T) @ xdot[t])
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# Training with  40 iterations
# ELBO: --:   0%|          | 0/40 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]
# ELBO (-): --:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
fig, axs = plt.subplots(5,1,figsize=(10,7), sharex=True)

# axs[0].plot(true_x)
axs[0].plot((Y[0] @ torch.linalg.pinv(pdlds.emissions ).T).data)
axs[0].set_ylabel("noisy x")
axs[1].plot(pdlds.offsets[0] + pdlds.latent[0])
axs[1].set_ylabel("x_smooth")
axs[2].plot(pdlds.offsets[0])
axs[2].set_ylabel("Trend")
axs[3].plot(pdlds.latent[0])
axs[3].set_ylabel("LDS")
axs[4].plot(pdlds.coefs[0])
# axs[4].set_ylim(-1,1)
axs[4].set_ylabel("inferred c")

plt.subplots_adjust(hspace=0)
plt.show()
